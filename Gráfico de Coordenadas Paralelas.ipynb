# %% [markdown]
# <a href="https://colab.research.google.com/github/extreme500/Laborat-rio-de-Visualiza-o-CGVis/blob/main/Gr%C3%A1fico%20de%20Coordenadas%20Paralelas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv("/Gaming_Academic_Performance.csv")

df_filtrado = df[
    (df["grades"] <= 100)
].copy()

fig = px.parallel_coordinates(
    df_filtrado,
    dimensions=[
        "grades",
        "sleep_hours",
        "gaming_hours",
        "study_hours"
    ],
    color="grades",
    color_continuous_scale=px.colors.sequential.Viridis,
    labels={
        "grades": "Notas",
        "sleep_hours": "Horas de sono",
        "gaming_hours": "Horas de jogo",
        "study_hours": "Horas de estudo"
    },
    title="Coordenadas Paralelas: Hábitos e Notas"
)

fig.update_layout(
    template="plotly_white"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
